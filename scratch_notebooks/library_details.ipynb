# %% [markdown]
# # Library Details
# ### this notebook includes the important antigenic sites of the H7 HA as well as the missing sites and missing mutations that I added back in

# %% [markdown]
# ## Antigenic sites (sequential)
# #### based on this paper https://www.cell.com/cell-host-microbe/abstract/S1931-3128(17)30344-X
# 69 - 74&emsp;&emsp;&emsp;Cb_antigenicSite <br>
# 118 - 119&emsp;&emsp;Sa_antigenicSite <br>
# 121 - 128&emsp;&emsp;RBS <br>
# 130 - 134&emsp;&emsp;Ca2_AntigenicSite <br>
# 142 - 149&emsp;&emsp;RBS <br>
# 145 - 160&emsp;&emsp;Sa_AntigenicSite <br>
# 161 - 164&emsp;&emsp;Ca1_AntigenicSite <br>
# 177 - 187&emsp;&emsp;RBS <br>
# 178 - 189&emsp;&emsp;Sb_AntigenicSite <br>
# 197 - 199&emsp;&emsp;Ca1_AntigenicSite <br>
# 210 - 219&emsp;&emsp;RBS <br>
# 214 - 216&emsp;&emsp;Ca2_AntigenicSite <br>
# 229 - 231&emsp;&emsp;Ca1_AntigenicSite <br>
# 507&emsp;&emsp;&emsp;&emsp;Transmembrane domain <br>

# %% [markdown]
# ## Spike in Sites
#
# The missing sites are as follow: Missing sites (sequential numbering): <br>
# [168 169 171 172 173 174 493 494 507 509 510] <br>
# 495 is also missing some sites but not all of the mutations are missing so that is being added back in with the other mutations in the mutation pools

# %%
import pandas as pd
